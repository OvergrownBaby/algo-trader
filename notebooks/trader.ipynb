# %% [markdown]
# Subscription

# %%
from futu import *
TRADING_SECURITIES = ['HK.01099', 'HK.00700']
FAST_MOVING_AVERAGE = 12
SLOW_MOVING_AVERAGE = 26
MACD_THRESHOLD = 0.003

quote_context = OpenQuoteContext(host='127.0.0.1', port=11111)  # Quotation context
quote_context.subscribe(TRADING_SECURITIES, [SubType.QUOTE, KLType.K_DAY, SubType.ORDER_BOOK])
ret, data = quote_context.get_cur_kline(code='HK.01099', num=10 + 1, ktype=KLType.K_DAY)
data
# Out:
# 2024-03-02 14:23:36,707 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=5, host=127.0.0.1, port=11111, user_id=16150358
#         code name             time_key   open  close   high    low   volume  \
# 0   HK.01099  N/A  2024-02-16 00:00:00  20.60  21.60  21.75  20.25  4283905
# 1   HK.01099  N/A  2024-02-19 00:00:00  21.60  21.40  21.60  21.15  1316291
# 2   HK.01099  N/A  2024-02-20 00:00:00  21.40  21.75  21.75  21.30  2463987
# 3   HK.01099  N/A  2024-02-21 00:00:00  21.55  21.70  22.20  21.15  4518948
# 4   HK.01099  N/A  2024-02-22 00:00:00  21.65  22.55  22.60  21.60  4301928
# 5   HK.01099  N/A  2024-02-23 00:00:00  22.45  22.30  22.65  22.10  3717789
# 6   HK.01099  N/A  2024-02-26 00:00:00  22.30  22.05  22.60  22.00  2788905
# 7   HK.01099  N/A  2024-02-27 00:00:00  21.65  22.20  22.40  21.60  3663938
# 8   HK.01099  N/A  2024-02-28 00:00:00  22.25  22.05  22.55  21.95  4790463
# 9   HK.01099  N/A  2024-02-29 00:00:00  22.05  21.95  22.45  21.80  7689353
# 10  HK.01099  N/A  2024-03-01 00:00:00  21.65  22.60  23.00  21.50  7333620
#
#        turnover  pe_ratio  turnover_rate  last_close
# 0    91887700.0     7.063        0.00319       20.60
# 1    28227811.0     6.998        0.00098       21.60
# 2    53230638.0     7.112        0.00184       21.40
# 3    98503276.0     7.096        0.00337       21.75
# 4    95607322.0     7.374        0.00321       21.70
# 5    83120981.0     7.292        0.00277       22.55
# 6    62099897.0     7.210        0.00208       22.30
# 7    81028995.0     7.259        0.00273       22.05
# 8   106117507.0     7.210        0.00357       22.20
# 9   169482423.0     7.177        0.00573       22.05
# 10  165344194.0     7.390        0.00547       21.95
# 2024-03-03 06:07:29,937 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=6, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 06:07:29,954 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=7, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 06:07:29,961 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=8, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 06:07:29,968 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=9, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 06:07:29,971 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=10, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 08:31:06,790 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=12, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 08:31:06,797 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=11, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 08:31:06,800 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=13, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 08:31:06,801 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=14, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 08:31:06,825 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=15, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:36:12,985 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=16, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:36:12,996 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=17, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:36:12,996 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=18, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:36:12,996 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=19, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:36:12,997 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=20, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:41:08,143 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=22, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:41:08,155 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=21, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:41:08,171 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=23, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:41:08,186 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=24, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:41:08,192 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=25, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:42:31,025 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=27, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:42:31,029 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=26, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:42:31,036 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=29, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:42:31,039 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=28, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:42:31,040 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=30, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:46:50,573 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=31, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:46:50,578 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=33, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:46:50,583 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=32, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:46:50,585 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=34, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 15:46:50,587 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=35, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 16:16:53,289 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=36, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 16:16:53,291 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=37, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 16:16:53,293 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=38, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 16:16:53,328 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=39, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 16:16:53,336 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=40, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 19:13:16,572 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=41, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 19:13:16,601 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=42, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 19:13:16,605 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=43, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 19:13:16,632 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=45, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 19:13:16,635 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=44, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 19:34:48,191 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=46, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 19:34:48,212 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=47, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 19:34:48,213 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=48, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 19:34:48,214 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=49, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 19:34:48,220 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=50, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 20:19:49,315 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=51, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 20:19:49,318 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=52, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 20:19:49,319 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=53, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 20:19:49,320 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=54, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 20:19:49,323 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=55, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 20:30:53,850 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=56, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 20:30:53,854 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=58, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 20:30:53,859 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=57, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 20:30:53,864 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=59, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 20:30:53,868 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=60, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:07:59,078 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=61, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:07:59,088 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=62, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:07:59,092 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=64, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:07:59,094 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=63, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:07:59,098 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=65, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:14:54,630 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=66, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:14:54,640 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=67, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:14:54,646 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=69, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:14:54,646 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=68, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:14:54,647 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=70, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:34:09,375 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=71, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:34:09,389 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=72, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:34:09,401 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=73, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:34:09,412 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=74, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-03 21:34:09,413 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=75, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-04 14:17:00,040 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=76, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-04 14:17:00,055 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=77, host=127.0.0.1, port=11111, user_id=16150358
# 2024-03-04 14:17:00,088 | 14198 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=78, host=127.0.0.1, port=11111, user_id=16150358

# %%
import time
class OrderBookTest(OrderBookHandlerBase):
    def on_recv_rsp(self, rsp_pb):
        ret_code, data = super(OrderBookTest,self).on_recv_rsp(rsp_pb)
        if ret_code != RET_OK:
            print("OrderBookTest: error, msg: %s"% data)
            return RET_ERROR, data
        print("OrderBookTest ", data) # OrderBookTest's own processing logic
        return RET_OK, data
quote_ctx = OpenQuoteContext(host='127.0.0.1', port=11111) # Create quote object
handler = OrderBookTest()
quote_ctx.set_handler(handler) # Set real-time swing callback
quote_ctx.subscribe(['SZ.002493'], [SubType.QUOTE, SubType.K_DAY]) # Subscribe to the order type, Futu OpenD starts to receive continuous push from the server
# time.sleep(15) # Set the script to receive Futu OpenD push duration to 15 seconds
# quote_ctx.close() # Close the current link, Futu OpenD will automatically cancel the corresponding type of subscription for the corresponding stock after 1 minute
# Out:
# 2024-02-26 16:18:25,943 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1858, host=127.0.0.1, port=11111, user_id=16150358
# (0, None)
# 2024-02-27 01:38:05,279 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1859, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,299 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1860, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,307 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1861, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,343 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1864, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,346 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1862, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,347 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1863, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,347 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1865, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,350 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1868, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,355 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1867, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,358 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1871, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,360 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1873, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,361 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1870, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,362 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1872, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,362 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1875, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,362 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1869, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,362 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1866, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,363 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1874, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,363 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1876, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,366 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1878, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,368 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1877, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,372 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1880, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,374 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1879, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,377 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1882, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,378 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1883, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,418 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1881, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,442 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1886, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,449 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1885, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,450 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1887, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,451 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1888, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,454 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1884, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,471 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1889, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,476 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1890, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,491 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1891, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,493 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1892, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,495 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1893, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,512 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1894, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,526 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1896, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,527 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1895, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:38:05,540 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1897, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,286 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1898, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,304 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1899, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,308 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1900, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,309 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1901, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,330 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1902, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,332 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1903, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,343 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1905, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,345 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1904, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,362 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1906, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,365 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1909, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,422 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1910, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,425 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1907, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,429 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1911, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,431 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1908, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,436 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1913, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,439 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1915, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,440 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1917, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,443 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1918, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18,447 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=1916, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-27 01:44:18
# 3  SZ.002493  N/A  2024-02-07 00:00:00  10.00  10.11  10.26   9.91  45523272
# 4  SZ.002493  N/A  2024-02-08 00:00:00  10.12  10.11  10.28  10.00  38996668
# 5  SZ.002493  N/A  2024-02-19 00:00:00  10.21  10.16  10.24  10.03  31180760
# 6  SZ.002493  N/A  2024-02-20 00:00:00  10.12  10.23  10.25  10.07  18738199
# 7  SZ.002493  N/A  2024-02-21 00:00:00  10.16  10.22  10.42  10.12  30969638
# 8  SZ.002493  N/A  2024-02-22 00:00:00  10.20  10.26  10.30  10.16  19962520
# 9  SZ.002493  N/A  2024-02-23 00:00:00  10.26  10.20  10.29  10.10  23313581
#
#        turnover  pe_ratio  turnover_rate  last_close
# 0  2.825618e+08       0.0        0.00317        9.46
# 1  3.769781e+08       0.0        0.00428        9.38
# 2  4.464984e+08       0.0        0.00480        9.38
# 3  4.597012e+08       0.0        0.00479       10.02
# 4  3.961216e+08       0.0        0.00411       10.11
# 5  3.157239e+08       0.0        0.00328       10.11
# 6  1.907534e+08       0.0        0.00197       10.16
# 7  3.186696e+08       0.0        0.00326       10.23
# 8  2.043843e+08       0.0        0.00210       10.22
# 9  2.372711e+08       0.0        0.00245       10.26  )

# %%
quote_ctx.close() # Close object to prevent the number of connextions from running out

# %%
trd_ctx = OpenSecTradeContext(host='127.0.0.1', port=11111)  # Create trade object
print(trd_ctx.place_order(price=500.0, qty=100, code="HK.00700", trd_side=TrdSide.BUY, trd_env=TrdEnv.SIMULATE))  # Placing an order through paper trading account (It is nessary to unlock trade by trading password for placing orders in the real environment.)

trd_ctx.close()  # Close object to prevent the number of connextions from running out
# Out:
# 2024-02-24 01:17:02,103 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=35, host=127.0.0.1, port=11111, user_id=16150358
# (0,        code stock_name trd_side order_type order_status            order_id  \
# 0  HK.00700       腾讯控股      BUY     NORMAL   SUBMITTING  476616228123106876
#
#      qty  price          create_time         updated_time  ...  \
# 0  100.0  500.0  2024-02-24 01:17:02  2024-02-24 01:17:02  ...
#
#    dealt_avg_price  last_err_msg remark time_in_force fill_outside_rth  \
# 0              0.0                                DAY              N/A
#
#   aux_price trail_type trail_value trail_spread currency
# 0       N/A        N/A         N/A          N/A      HKD
#
# [1 rows x 21 columns])
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 500.0, 'TradeSide': 'BUY', 'Quantity': 100.0}

# %% [markdown]
# Simple Strategy: Buy when MA1 >= MA3, vice versa

# %%
password = next(open("pw.txt"))
password
# Out:
# '596902'

# %%
from futu import *

############################ Global Variables ############################
FUTU_OPEND_ADDRESS = '127.0.0.1'  # Futu OpenD listening address
FUTU_OPEND_PORT = 11111  # Futu OpenD listening port

TRADING_ENVIRONMENT = TrdEnv.SIMULATE  # Trading environment: REAL / SIMULATE
TRADING_MARKET = TrdMarket.HK  # Transaction market authority, used to filter accounts
TRADING_PWD = '123456'  # Trading password, used to unlock trading for real trading environment
TRADING_PERIOD = KLType.K_1M  # Underlying trading time period
TRADING_SECURITY = 'HK.00700'  # Underlying trading security code
FAST_MOVING_AVERAGE = 1  # Parameter for fast moving average
SLOW_MOVING_AVERAGE = 3  # Parameter for slow moving average

quote_context = OpenQuoteContext(host=FUTU_OPEND_ADDRESS, port=FUTU_OPEND_PORT)  # Quotation context
trade_context = OpenSecTradeContext(filter_trdmarket=TRADING_MARKET, host=FUTU_OPEND_ADDRESS, port=FUTU_OPEND_PORT, security_firm=SecurityFirm.FUTUSECURITIES)  # Trading context. It must be consistent with the underlying varieties.


# Unlock trade
def unlock_trade():
    if TRADING_ENVIRONMENT == TrdEnv.REAL:
        ret, data = trade_context.unlock_trade(TRADING_PWD)
        if ret != RET_OK:
            print('Unlock trade failed: ', data)
            return False
        print('Unlock Trade success!')
    return True


# Check if it is regular trading time for underlying security
def is_normal_trading_time(code):
    ret, data = quote_context.get_market_state([code])
    if ret != RET_OK:
        print('Get market state failed: ', data)
        return False
    market_state = data['market_state'][0]
    '''
    MarketState.MORNING            HK and A-share morning
    MarketState.AFTERNOON          HK and A-share afternoon, US opening hours
    MarketState.FUTURE_DAY_OPEN    HK, SG, JP futures day market open
    MarketState.FUTURE_OPEN        US futures open
    MarketState.FUTURE_BREAK_OVER  Trading hours of U.S. futures after break
    MarketState.NIGHT_OPEN         HK, SG, JP futures night market open
    '''
    if market_state == MarketState.MORNING or \
                    market_state == MarketState.AFTERNOON or \
                    market_state == MarketState.FUTURE_DAY_OPEN  or \
                    market_state == MarketState.FUTURE_OPEN  or \
                    market_state == MarketState.FUTURE_BREAK_OVER  or \
                    market_state == MarketState.NIGHT_OPEN:
        return True
    print('It is not regular trading hours.')
    return False


# Get positions
def get_holding_position(code):
    holding_position = 0
    ret, data = trade_context.position_list_query(code=code, trd_env=TRADING_ENVIRONMENT)
    if ret != RET_OK:
        print('获取持仓数据失败：', data)
        return None
    else:
        for qty in data['qty'].values.tolist():
            holding_position += qty
        print('【持仓状态】 {} 的持仓数量为：{}'.format(TRADING_SECURITY, holding_position))
    return holding_position



# Query for candlesticks, calculate moving average value and judge bull or bear
def calculate_bull_bear(code, fast_param, slow_param):
    if fast_param <= 0 or slow_param <= 0:
        return 0
    if fast_param > slow_param:
        return calculate_bull_bear(code, slow_param, fast_param)
    ret, data = quote_context.get_cur_kline(code=code, num=slow_param + 1, ktype=TRADING_PERIOD)
    if ret != RET_OK:
        print('Get candlestick value failed: ', data)
        return 0
    candlestick_list = data['close'].values.tolist()[::-1]
    fast_value = None
    slow_value = None
    if len(candlestick_list) > fast_param:
        fast_value = sum(candlestick_list[1: fast_param + 1]) / fast_param
    if len(candlestick_list) > slow_param:
        slow_value = sum(candlestick_list[1: slow_param + 1]) / slow_param
    if fast_value is None or slow_value is None:
        return 0
    return 1 if fast_value >= slow_value else -1


# Get ask1 and bid1 from order book
def get_ask_and_bid(code):
    ret, data = quote_context.get_order_book(code, num=1)
    if ret != RET_OK:
        print('Get order book failed: ', data)
        return None, None
    return data['Ask'][0][0], data['Bid'][0][0]


# Open long positions
def open_position(code):
    # Get order book data
    ask, bid = get_ask_and_bid(code)

    # Get quantity
    open_quantity = calculate_quantity()

    # Check whether buying power is enough
    if is_valid_quantity(TRADING_SECURITY, open_quantity, ask):
        # Place order
        ret, data = trade_context.place_order(price=ask, qty=open_quantity, code=code, trd_side=TrdSide.BUY,
                                              order_type=OrderType.NORMAL, trd_env=TRADING_ENVIRONMENT,
                                              remark='moving_average_strategy')
        if ret != RET_OK:
            print('Open position failed: ', data)
    else:
        print('Maximum quantity that can be bought less than transaction quantity.')


# Close position
def close_position(code, quantity):
    # Get order book data
    ask, bid = get_ask_and_bid(code)

    # Check quantity
    if quantity == 0:
        print('Invalid order quantity.')
        return False

    # Close position
    ret, data = trade_context.place_order(price=bid, qty=quantity, code=code, trd_side=TrdSide.SELL,
                   order_type=OrderType.NORMAL, trd_env=TRADING_ENVIRONMENT, remark='moving_average_strategy')
    if ret != RET_OK:
        print('Close position failed: ', data)
        return False
    return True


# Calculate order quantity
def calculate_quantity():
    price_quantity = 0
    # Use minimum lot size
    ret, data = quote_context.get_market_snapshot([TRADING_SECURITY])
    if ret != RET_OK:
        print('Get market snapshot failed: ', data)
        return price_quantity
    price_quantity = data['lot_size'][0]
    return price_quantity


# Check the buying power is enough for the quantity
def is_valid_quantity(code, quantity, price):
    ret, data = trade_context.acctradinginfo_query(order_type=OrderType.NORMAL, code=code, price=price,
                                                   trd_env=TRADING_ENVIRONMENT)
    if ret != RET_OK:
        print('Get max long/short quantity failed: ', data)
        return False
    max_can_buy = data['max_cash_buy'][0]
    max_can_sell = data['max_sell_short'][0]
    if quantity > 0:
        return quantity < max_can_buy
    elif quantity < 0:
        return abs(quantity) < max_can_sell
    else:
        return False


# Show order status
def show_order_status(data):
    order_status = data['order_status'][0]
    order_info = dict()
    order_info['Code'] = data['code'][0]
    order_info['Price'] = data['price'][0]
    order_info['TradeSide'] = data['trd_side'][0]
    order_info['Quantity'] = data['qty'][0]
    print('[OrderStatus]', order_status, order_info)


############################ Fill in the functions below to finish your trading strategy ############################
# Strategy initialization. Run once when the strategy starts
def on_init():
    # unlock trade (no need to unlock for paper trading)
    if not unlock_trade():
        return False
    print('************  Strategy Starts ***********')
    return True


# Run once for each tick. You can write the main logic of the strategy here
def on_tick():
    pass


# Run once for each new candlestick. You can write the main logic of the strategy here
def on_bar_open():
    # Print seperate line
    print('*****************************************')

    # Only trade during regular trading hours
    if not is_normal_trading_time(TRADING_SECURITY):
        return

    # Query for candlesticks, and calculate moving average value
    bull_or_bear = calculate_bull_bear(TRADING_SECURITY, FAST_MOVING_AVERAGE, SLOW_MOVING_AVERAGE)

    # Get positions
    holding_position = get_holding_position(TRADING_SECURITY)

    # Trading signals
    if holding_position == 0:
        if bull_or_bear == 1:
            print('[Signal] Long signal. Open long positions.')
            open_position(TRADING_SECURITY)
        else:
            print('[Signal] Short signal. Do not open short positions.')
    elif holding_position > 0:
        if bull_or_bear == -1:
            print('[Signal] Short signal. Close positions.')
            close_position(TRADING_SECURITY, holding_position)
        else:
            print('[Signal] Long signal. Do not add positions.')


# Run once when an order is filled
def on_fill(data):
    pass


# Run once when the status of an order changes
def on_order_status(data):
    if data['code'][0] == TRADING_SECURITY:
        show_order_status(data)


############################### Framework code, which can be ignored ###############################
class OnTickClass(TickerHandlerBase):
    def on_recv_rsp(self, rsp_pb):
        on_tick()


class OnBarClass(CurKlineHandlerBase):
    last_time = None
    def on_recv_rsp(self, rsp_pb):
        ret_code, data = super(OnBarClass, self).on_recv_rsp(rsp_pb)
        if ret_code == RET_OK:
            cur_time = data['time_key'][0]
            if cur_time != self.last_time and data['k_type'][0] == TRADING_PERIOD:
                if self.last_time is not None:
                    on_bar_open()
                self.last_time = cur_time


class OnOrderClass(TradeOrderHandlerBase):
    def on_recv_rsp(self, rsp_pb):
        ret, data = super(OnOrderClass, self).on_recv_rsp(rsp_pb)
        if ret == RET_OK:
            on_order_status( data)


class OnFillClass(TradeDealHandlerBase):
    def on_recv_rsp(self, rsp_pb):
        ret, data = super(OnFillClass, self).on_recv_rsp(rsp_pb)
        if ret == RET_OK:
            on_fill(data)


# Main function
if __name__ == '__main__':
    # Strategy initialization
    if not on_init():
        print('Strategy initialization failed, exit script!')
        quote_context.close()
        trade_context.close()
    else:
        # Set up callback functions
        quote_context.set_handler(OnTickClass())
        quote_context.set_handler(OnBarClass())
        trade_context.set_handler(OnOrderClass())
        trade_context.set_handler(OnFillClass())

        # Subscribe tick-by-tick, candlestick and order book of the underlying trading security
        quote_context.subscribe(code_list=[TRADING_SECURITY], subtype_list=[SubType.TICKER, SubType.ORDER_BOOK, TRADING_PERIOD])
# Out:
# 2024-02-24 03:26:54,580 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=52, host=127.0.0.1, port=11111, user_id=16150358
# 2024-02-24 03:26:54,584 | 22345 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=53, host=127.0.0.1, port=11111, user_id=16150358
# ************  Strategy Starts ***********
# [OrderStatus] CANCELLED_ALL {'Code': 'HK.00700', 'Price': 500.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 290.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 500.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 500.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 500.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 500.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 500.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 500.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] CANCELLED_ALL {'Code': 'HK.00700', 'Price': 290.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] CANCELLED_ALL {'Code': 'HK.00700', 'Price': 500.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] CANCELLED_ALL {'Code': 'HK.00700', 'Price': 500.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] CANCELLED_ALL {'Code': 'HK.00700', 'Price': 500.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 291.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 291.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] CANCELLED_ALL {'Code': 'HK.00700', 'Price': 291.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 291.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 291.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] CANCELLED_ALL {'Code': 'HK.00700', 'Price': 291.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 291.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 291.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 291.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 291.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 291.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 291.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：300.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.4, 'TradeSide': 'SELL', 'Quantity': 300.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.4, 'TradeSide': 'SELL', 'Quantity': 300.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.4, 'TradeSide': 'SELL', 'Quantity': 300.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 285.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 285.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 285.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# Get market state failed:  PacketErr.Timeout
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# Close position failed:  更新持仓失败
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：200.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：200.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 200.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 200.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 200.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 285.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# Close position failed:  持仓不足
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 287.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 287.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 287.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：200.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'SELL', 'Quantity': 200.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'SELL', 'Quantity': 200.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'SELL', 'Quantity': 200.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# Get market state failed:  PacketErr.Timeout
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 286.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# ...
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 281.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 281.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 281.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 281.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 281.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 281.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 281.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 281.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 281.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 281.8, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 282.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 282.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 282.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 282.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 282.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 282.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 281.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 281.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 281.8, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 282.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 282.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 282.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 281.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 281.6, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 282.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 282.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 282.2, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 283.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 283.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 283.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 282.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 282.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 282.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 282.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 282.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 282.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 282.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 282.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 282.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 282.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 282.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 282.0, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Short signal. Do not open short positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 282.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 282.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 282.4, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 282.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 282.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 282.4, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 283.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 283.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 283.0, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Long signal. Do not add positions.
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：100.0
# [Signal] Short signal. Close positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 283.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 283.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# [OrderStatus] FILLED_ALL {'Code': 'HK.00700', 'Price': 283.2, 'TradeSide': 'SELL', 'Quantity': 100.0}
# *****************************************
# 【持仓状态】 HK.00700 的持仓数量为：0.0
# [Signal] Long signal. Open long positions.
# [OrderStatus] SUBMITTING {'Code': 'HK.00700', 'Price': 283.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# [OrderStatus] SUBMITTED {'Code': 'HK.00700', 'Price': 283.6, 'TradeSide': 'BUY', 'Quantity': 100.0}
# *****************************************
# It is not regular trading hours.
